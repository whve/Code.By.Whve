# %%
# 导入snp csv,生成ndarry数组
import numpy as np
import pandas as pd
hrj = pd.read_csv(r'F:\[calcium]gwas-association-downloaded_2019-03-03-EFO_0004838-withChildTraits.tsv',delimiter = '\t')
jib = pd.read_csv(r'F:\[Osteo..]fa2stu.MAF0.005.pos.out',delimiter = '\t')

# %%
pd.set_option('display.max_columns', None)
hrj
# Out:
#    DATE ADDED TO CATALOG  PUBMEDID       FIRST AUTHOR        DATE  \
# 0             2017-04-21  27915449            Corre T  2016-12-03
# 1             2017-04-21  27915449            Corre T  2016-12-03
# 2             2017-04-21  27915449            Corre T  2016-12-03
# 3             2015-11-20  25886283            Chang X  2015-04-17
# 4             2015-11-20  25886283            Chang X  2015-04-17
# 5             2015-11-20  25886283            Chang X  2015-04-17
# 6             2015-11-20  25886283            Chang X  2015-04-17
# 7             2015-11-20  25886283            Chang X  2015-04-17
# 8             2015-11-20  25886283            Chang X  2015-04-17
# 9             2015-11-21  25972035  Vinayagamoorthy N  2015-05-14
# 10            2015-11-21  25972035  Vinayagamoorthy N  2015-05-14
# 11            2015-11-21  25972035  Vinayagamoorthy N  2015-05-14
# 12            2015-11-21  25972035  Vinayagamoorthy N  2015-05-14
# ...

# %%
jib.head()
# Out:
#    chromosome  position      rs_number reference_allele other_allele  \
# 0           1  12775981  chr1:12775981                G            T
# 1           1  12776140  chr1:12776140                C            T
# 2           1  12776161  chr1:12776161                G            A
# 3           1  12776218  chr1:12776218                A            C
# 4           1  12776441  chr1:12776441                C            T
#
#         eaf      beta        se  beta_95L  beta_95U         z   p-value  \
# 0  0.955927 -0.062953  0.040715 -0.142754  0.016849 -1.546183  0.129581
# 1  0.997375  0.031278  0.263981 -0.486125  0.548682  0.118487  0.907511
# 2  0.965792 -0.056473  0.040835 -0.136511  0.023564 -1.382954  0.175175
# 3  0.133095  0.027112  0.023202 -0.018364  0.072588  1.168497  0.251993
# 4  0.999364  0.472124  0.349409 -0.212718  1.156966  1.351206  0.185290
#
#    _-log10_p-value  q_statistic  q_p-value        i2  n_studies  n_samples  \
# ...

# %%
jib
# Out:
#          chromosome  position       rs_number reference_allele other_allele  \
# 0                 1  12775981   chr1:12775981                G            T
# 1                 1  12776140   chr1:12776140                C            T
# 2                 1  12776161   chr1:12776161                G            A
# 3                 1  12776218   chr1:12776218                A            C
# 4                 1  12776441   chr1:12776441                C            T
# 5                 1  12779563   chr1:12779563                C            T
# 6                 1  12779578   chr1:12779578                G            A
# 7                 1  12780816   chr1:12780816                A            C
# 8                 1  12785200   chr1:12785200                T            C
# 9                 1  12785295   chr1:12785295                C            T
# 10                1  12785749   chr1:12785749                C            T
# ...

# %%
# 同时用标签切片和标签名索引来获取数据
# df.loc['20130102':'20130104',['A','B']]
hrj2=hrj.loc[:, ['SNPS', 'OR or BETA','95% CI (TEXT)','P-VALUE','RISK ALLELE FREQUENCY']]
hrj2
# Out:
#           SNPS  OR or BETA                               95% CI (TEXT)  \
# 0     rs172639    0.113900                 [0.082-0.145] unit increase
# 1     rs884127    0.094600                 [0.063-0.126] unit increase
# 2    rs7447593    0.108600                 [0.072-0.145] unit increase
# 3    rs3764796    0.065340                [0.038-0.093] mg/dl increase
# 4    rs7032317    0.044420          [-0.06348--0.02536] mg/dl decrease
# 5    rs2648708    0.069600          [-0.10002--0.03918] mg/dl decrease
# 6    rs1472147    0.048800                [0.028-0.070] mg/dl increase
# 7    rs1801725    0.056600                         [NR] mg/dl increase
# 8    rs3764796    0.062400                         [NR] mg/dl increase
# 9   rs13068893    0.002080               [0.0013-0.0028] unit decrease
# 10   rs4678181    0.002020               [0.0013-0.0028] unit decrease
# 11  rs12517041    0.004110               [0.0025-0.0057] unit increase
# ...

# %%
jib2=jib.loc[:, ['rs_number', 'reference_allele','other_allele','beta','se','p-value']]

# %%
# 重命名
jib21=jib2.rename(columns={'rs_number':'SNPS'})

# %%
jib21
# Out:
#                    SNPS reference_allele other_allele      beta        se  \
# 0         chr1:12775981                G            T -0.062953  0.040715
# 1         chr1:12776140                C            T  0.031278  0.263981
# 2         chr1:12776161                G            A -0.056473  0.040835
# 3         chr1:12776218                A            C  0.027112  0.023202
# 4         chr1:12776441                C            T  0.472124  0.349409
# 5         chr1:12779563                C            T  0.120193  0.244897
# 6         chr1:12779578                G            A  0.428099  0.282593
# 7         chr1:12780816                A            C -0.227194  0.192175
# 8         chr1:12785200                T            C  0.100777  0.230132
# 9         chr1:12785295                C            T -0.039722  0.087102
# 10        chr1:12785749                C            T  0.011247  0.032314
# 11        chr1:12785750                G            A -0.197674  0.216597
# ...

# %%
hvzs=pd.merge(hrj2,jib21,how='inner',on='SNPS')

# %%
hvzs
# Out:
#           SNPS  OR or BETA                       95% CI (TEXT)       P-VALUE  \
# 0     rs172639    0.113900         [0.082-0.145] unit increase  2.000000e-12
# 1     rs884127    0.094600         [0.063-0.126] unit increase  3.000000e-09
# 2    rs7447593    0.108600         [0.072-0.145] unit increase  6.000000e-09
# 3    rs7032317    0.044420  [-0.06348--0.02536] mg/dl decrease  5.000000e-06
# 4    rs2648708    0.069600  [-0.10002--0.03918] mg/dl decrease  8.000000e-06
# 5    rs1472147    0.048800        [0.028-0.070] mg/dl increase  7.000000e-06
# 6   rs13068893    0.002080       [0.0013-0.0028] unit decrease  4.000000e-08
# 7    rs4678181    0.002020       [0.0013-0.0028] unit decrease  1.000000e-07
# 8   rs12517041    0.004110       [0.0025-0.0057] unit increase  8.000000e-07
# 9    rs3109133    0.003150       [0.0019-0.0044] unit decrease  1.000000e-06
# 10   rs4468442    0.001920       [0.0011-0.0027] unit decrease  3.000000e-06
# ...

# %%
hvzs2=hvzs[hvzs['P-VALUE']<5*10**-8]

# %%
# 该命令参数是猜的，hvzs3=hvzs2[hvzs2['i2']<0.01]

# %%
hvzs2
# Out:
#           SNPS  OR or BETA                      95% CI (TEXT)       P-VALUE  \
# 0     rs172639    0.113900        [0.082-0.145] unit increase  2.000000e-12
# 1     rs884127    0.094600        [0.063-0.126] unit increase  3.000000e-09
# 2    rs7447593    0.108600        [0.072-0.145] unit increase  6.000000e-09
# 6   rs13068893    0.002080      [0.0013-0.0028] unit decrease  4.000000e-08
# 22  rs17251221    0.060000          [0.05-0.07] unit increase  2.000000e-22
# 23  rs17251221         NaN                                NaN  2.000000e-51
# 30   rs4685771    0.033550  [0.023-0.044] unit increase novel  3.000000e-10
# 31  rs13103813    0.030900   [0.02-0.042] unit decrease novel  2.000000e-08
# 32  rs62462685    0.036960   [0.024-0.05] unit decrease novel  4.000000e-08
# 33  rs13301969    0.032730  [0.022-0.043] unit increase novel  1.000000e-09
# 34  rs11101061    0.054330  [0.036-0.073] unit decrease novel  1.000000e-08
# ...

# %%
hvzs2.to_csv(r'F:\whve.myDataFrame.csv')
