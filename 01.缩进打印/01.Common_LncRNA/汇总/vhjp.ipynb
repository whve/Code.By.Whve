# %%
import re 
with open(r'E:\whve.AD.blood\buis.se.txt') as se:
          
    for i in se:
        b=re.findall(r'\d+.\d+',i)
        print((eval(b[1])-eval(b[0]))/2/1.96)
# Out:
# 0.005102040816326535
# 0.0051020408163265285
# 0.005102040816326532
# 0.015306122448979591
# 0.0051020408163265285
# 0.015306122448979591
# 0.005102040816326532
# 0.00510204081632653
# 0.00510204081632653
# 0.010204081632653064
# 0.007653061224489796
# 0.005102040816326532
# 0.005102040816326532
# 0.005102040816326531
# 0.005102040816326531
# 0.020408163265306124
# 0.020408163265306124
# 0.007653061224489796
# 0.013010204081632651
# 0.006887755102040816
# 0.011224489795918367
# 0.013775510204081635
# 0.007142857142857141
# 0.009948979591836734
# 0.008163265306122448
# 0.008928571428571428
# 0.007142857142857144
# 0.009183673469387752
# 0.006887755102040816
# 0.007142857142857143
# 0.006887755102040817
# 0.00816326530612245
# 0.0071428571428571435
# 0.0068877551020408165
# 0.1275510204081633
# 0.09948979591836737
# 0.07653061224489795
# 0.15051020408163265
# 0.09948979591836735
# 0.10969387755102042
# 0.10714285714285712
# 0.06887755102040814
# 0.13775510204081634
# ...

# %%
# 导入snp csv,生成ndarry数组
import numpy as np
import pandas as pd
hrj = pd.read_csv(r'F:\AD\[01]AD\[calcium].tsv',delimiter = '\t')

pd.set_option('display.max_columns', None)

hrj2=hrj.loc[:, ['SNPS', 'OR or BETA','95% CI (TEXT)','P-VALUE','RISK ALLELE FREQUENCY']]
hrj2
# Out:
#           SNPS  OR or BETA                               95% CI (TEXT)  \
# 0     rs172639    0.113900                 [0.082-0.145] unit increase
# 1     rs884127    0.094600                 [0.063-0.126] unit increase
# 2    rs7447593    0.108600                 [0.072-0.145] unit increase
# 3    rs3764796    0.065340                [0.038-0.093] mg/dl increase
# 4    rs7032317    0.044420          [-0.06348--0.02536] mg/dl decrease
# 5    rs2648708    0.069600          [-0.10002--0.03918] mg/dl decrease
# 6    rs1472147    0.048800                [0.028-0.070] mg/dl increase
# 7    rs1801725    0.056600                         [NR] mg/dl increase
# 8    rs3764796    0.062400                         [NR] mg/dl increase
# 9   rs13068893    0.002080               [0.0013-0.0028] unit decrease
# 10   rs4678181    0.002020               [0.0013-0.0028] unit decrease
# 11  rs12517041    0.004110               [0.0025-0.0057] unit increase
# ...

# %%
hrj3=hrj2[hrj2['P-VALUE']<5*10**-8]
hrj3
# Out:
#           SNPS  OR or BETA                               95% CI (TEXT)  \
# 0     rs172639    0.113900                 [0.082-0.145] unit increase
# 1     rs884127    0.094600                 [0.063-0.126] unit increase
# 2    rs7447593    0.108600                 [0.072-0.145] unit increase
# 9   rs13068893    0.002080               [0.0013-0.0028] unit decrease
# 26  rs17251221    0.060000                   [0.05-0.07] unit increase
# 34  rs17251221         NaN                                         NaN
# 35   rs4685771    0.033550           [0.023-0.044] unit increase novel
# 36  rs13103813    0.030900            [0.02-0.042] unit decrease novel
# 37  rs62462685    0.036960            [0.024-0.05] unit decrease novel
# 38  rs13301969    0.032730           [0.022-0.043] unit increase novel
# 39  rs11101061    0.054330           [0.036-0.073] unit decrease novel
# 40   rs3750996    0.044600            [0.029-0.06] unit decrease novel
# ...

# %%
hrj3.to_csv(r'F:\AD\[01]AD\whve.Ca1.csv')

# %%
import re 
with open(r'F:\AD\[01]AD\se_py\Ca.txt') as se:
          
    for i in se:
        b=re.findall(r'\d+.\d+',i)
        print((eval(b[1])-eval(b[0]))/2/1.96)
# Out:
# C:\whve\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                  Beijing-1_BJ_49  Ling_TW_65  TLA_LN_71
# Nakayama_JP_35              95.9         NaN        NaN
# Nakayama_JP_35               NaN         NaN       97.9
# Beijing-1_BJ_49              NaN         NaN       97.9
# Nakayama_JP_35               NaN        97.9        NaN
# Beijing-1_BJ_49              NaN        97.9        NaN
# TLA_LN_71                    NaN       100.0        NaN

# %%
(95.9+97.9*4+100)/6
# Out:
# 97.91666666666667

# %%
jun.iloc[0:1,75:76]
# Out:
#                 HYZ_YN_79
# Nakayama_JP_35       97.9
